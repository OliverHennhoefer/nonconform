# %% [markdown]
# # Detached Calibration
#
# Fit the base detector first, then attach conformal calibration data with `calibrate(...)` before computing p-values.

# %%
import pandas as pd
from oddball import Dataset, load
from pyod.models.iforest import IForest
from scipy.stats import false_discovery_control

from nonconform import ConformalDetector, Split
from nonconform.metrics import false_discovery_rate, statistical_power

# %% [markdown]
# ## Setup
#
# Split the training data into an initial detector-fit split and a later calibration split.

# %%
x_train, x_test, y_test = load(Dataset.SHUTTLE, setup=True, seed=1)

split_idx = int(0.8 * len(x_train))
x_fit = x_train[:split_idx]
x_calib = x_train[split_idx:]
alpha = 0.1

# %% [markdown]
# ## Detached Workflow
#
# The base detector is already fit when it is passed into `ConformalDetector`; `calibrate(...)` adds the conformal reference distribution.

# %%
base_detector = IForest(random_state=1)
base_detector.fit(x_fit)

ce = ConformalDetector(
    detector=base_detector,
    strategy=Split(n_calib=0.2),
    score_polarity="higher_is_anomalous",
    seed=1,
)

ce.calibrate(x_calib)
p_values = ce.compute_p_values(x_test)

# %%
decisions = false_discovery_control(p_values, method="bh") <= alpha
result = pd.DataFrame(
    [
        {
            "discoveries": int(decisions.sum()),
            "fdr": false_discovery_rate(y=y_test, y_hat=decisions),
            "power": statistical_power(y=y_test, y_hat=decisions),
        }
    ]
)
print(result.to_string(index=False, float_format=lambda x: f"{x:.4f}"))
# Out:
#  discoveries    fdr  power
#          106 0.0755 0.9800

# %% [markdown]
# ## How to read this
#
# Detached calibration is useful when the detector fit is fixed. New calibration data changes the conformal p-values, not the underlying detector.
